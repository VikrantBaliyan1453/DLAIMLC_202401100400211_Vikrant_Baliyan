# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Embedding

# Fix seed
np.random.seed(42)
tf.random.set_seed(42)

# Load data
max_features = 10000
maxlen = 200

(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)

x_train = pad_sequences(x_train, maxlen=maxlen)
x_test = pad_sequences(x_test, maxlen=maxlen)

# Model
model = Sequential([
    Embedding(max_features, 64, input_length=maxlen),
    LSTM(64),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Train
history = model.fit(
    x_train, y_train,
    epochs=3,
    batch_size=64,
    validation_split=0.2
)

# Evaluate
loss, acc = model.evaluate(x_test, y_test)
print("Test Accuracy:", acc)
# Out:
# 2026-05-04 19:43:29.966979: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/sudhanshu-gill/anaconda3/lib/python3.11/site-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 2026-05-04 19:43:47.665934: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Epoch 1/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 50s 146ms/step - accuracy: 0.7885 - loss: 0.4458 - val_accuracy: 0.8064 - val_loss: 0.4217
# Epoch 2/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 46s 146ms/step - accuracy: 0.8795 - loss: 0.2982 - val_accuracy: 0.8522 - val_loss: 0.3597
# Epoch 3/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 44s 140ms/step - accuracy: 0.9237 - loss: 0.2103 - val_accuracy: 0.8632 - val_loss: 0.3388
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 34ms/step - accuracy: 0.8598 - loss: 0.3510
# Test Accuracy: 0.8597999811172485
